# %%
from whooshai.flow import train, inference

# %%
train()
# Out:
# node number: 10000
# training sample: 9000.0
# validation sample: 500.0
# testing sample: 1000.0
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Epoch 0 / 22 ### 2.6989526748657227 --- 0.4951111111111111 --- 0.526
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Epoch 1 / 22 ### 1.2937006950378418 --- 0.5016666666666667 --- 0.526
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Epoch 2 / 22 ### 1.1643155813217163 --- 0.49577777777777776 --- 0.526
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Epoch 3 / 22 ### 1.0982050895690918 --- 0.49366666666666664 --- 0.526
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Epoch 4 / 22 ### 1.6927837133407593 --- 0.4875555555555556 --- 0.526
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Epoch 5 / 22 ### 2.3347110748291016 --- 0.49033333333333334 --- 0.526
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Epoch 6 / 22 ### 2.3270068168640137 --- 0.49166666666666664 --- 0.526
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Epoch 7 / 22 ### 1.1204465627670288 --- 0.5015555555555555 --- 0.526
#
#
#
#
#
#
#
#
#
#
#
#
# ...

# %%
inference()
# Out:
# node number: 10000
# training sample: 9000.0
# validation sample: 500.0
# testing sample: 1000.0
# 0.0 1.0
# 10000 87224
# 10000 87224
#
# construct time: 0.2964
# shortest path time: 24.211946964263916
# pathlen:2, #87224
# pathlen:3, #48416
# generate path time: 7.119025945663452
# pathM saved
# {0: {0: {2: {'indices': tensor([[   0,    1,    1,  ..., 9997, 9998, 9999],
#             [ 101,  102,  101,  ..., 9997, 9998, 9999]]),
#     'values': tensor([[0.0000e+00, 1.0100e+02],
#             [1.0000e+00, 1.0200e+02],
#             [1.0000e+00, 1.0100e+02],
#             ...,
#             [9.9970e+03, 9.9970e+03],
#             [9.9980e+03, 9.9980e+03],
#             [9.9990e+03, 9.9990e+03]])},
#    3: {'indices': tensor([[   1,    2,    3,  ..., 9997, 9998, 9999],
#             [   0,    1,    1,  ..., 9997, 9998, 9999]]),
#     'values': tensor([[1.0000e+00, 1.0100e+02, 0.0000e+00],
#             [2.0000e+00, 1.0200e+02, 1.0000e+00],
# ...
